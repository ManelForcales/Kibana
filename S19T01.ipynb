# %%
from IPython import display

# %% [markdown]
# ### Nivell 1
# - Exercici 1
#
# Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# + per aquest exemple specific m'he creat un compte a https://www.elastic.co/es
# + amb aquest compte trial puc entrar al sistema i treballar desde l'aplicatiu WEB

# %% [markdown]
# + creo un deployment

# %%
display.Image('picture_1.png')

# %% [markdown]
# + i desde aqui me'n vaig a Quick Link de Kibana on em mostra les diferents opcions de visualització

# %%
display.Image('picture_2.png')

# %% [markdown]
# + me'n vaig a Dashboard

# %%
display.Image('picture_3.png')

# %% [markdown]
# + agafaré el 2nd exemple per treballar amb les dades 'Global Flight Dashboard' que hi ha d'exemple

# %% [markdown]
# + s'obre el dashboard on puc editar les diferentes visualitzacions

# %%
display.Image('picture_4.png')

# %% [markdown]
# + A share es pot guardar un PDF del dashboard

# %% [markdown]
# ### Nivell 2
# - Exercici 1
#
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# + per realitzar aquesta tasca pujo el seguent CSV al elastic cloud
# + Dades de les diferents olimpiades, noms, pais, sexe,sport,..
# + el dataset es el seguent:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('modern_games.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M  23.0   170.0    60.0        China  CHN
# 2   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 3   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 4   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#    Year  Season         City          Sport Medal
# 0  1992  Summer    Barcelona     Basketball   NaN
# 1  2012  Summer       London           Judo   NaN
# 2  1988  Winter      Calgary  Speed Skating   NaN
# 3  1988  Winter      Calgary  Speed Skating   NaN
# 4  1992  Winter  Albertville  Speed Skating   NaN

# %% [markdown]
# + he pujat el CSV al elastic cloud y he començat a construir el DASHBOARD amb les dades de les olimpiades

# %%
display.Image('report.PNG')

# %% [markdown]
# al git tambe es pot trobar el report : MFF_games_S19T01_exercisi_2.pdf

# %%
df_1920 = df[df.Year >=1920]

# %%
df_subset=df_1920[['Year','Sex','Team','Age']]

# %%
df_subset[df_subset['Age'].isnull()]
# Out:
#         Year Sex         Team  Age
# 147     1948   M         Iran  NaN
# 152     1924   M     Bulgaria  NaN
# 153     1924   M     Bulgaria  NaN
# 162     1972   M        Sudan  NaN
# 212     1920   M        Egypt  NaN
# ...      ...  ..          ...  ...
# 270679  1948   M    Argentina  NaN
# 270774  1984   M       Zambia  NaN
# 270793  1928   M  Switzerland  NaN
# 270804  1948   M        Chile  NaN
# 270805  1928   M        Chile  NaN
#
# [6699 rows x 4 columns]

# %%
df_subset["Age"] = df_subset.groupby(['Year','Sex','Team']).transform(lambda x: x.fillna(x.mean()))
# Out:
# <ipython-input-53-a84b197d3af9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["Age"] = df_subset.groupby(['Year','Sex','Team']).transform(lambda x: x.fillna(x.mean()))

# %%
df_subset[df_subset['Age'].isnull()]
# Out:
#         Year Sex                  Team  Age
# 570     1984   M  United Arab Emirates  NaN
# 619     1980   M                 Libya  NaN
# 653     1980   F   Congo (Brazzaville)  NaN
# 852     1988   M                 Niger  NaN
# 872     1956   M           Afghanistan  NaN
# ...      ...  ..                   ...  ...
# 267438  1980   M                 Libya  NaN
# 267439  1980   M                 Libya  NaN
# 267962  1980   M                 Libya  NaN
# 270062  1952   M             Marie-Tim  NaN
# 270453  1980   M                 Libya  NaN
#
# [228 rows x 4 columns]

# %%
df_fill_age = df_male.groupby(['Year','Season','Team']).transform(lambda x: x.fillna(x.mean()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a2f706d4a5fa> in <module>
# ----> 1 df_fill_age = df_male.groupby(['Year','Season','Team']).transform(lambda x: x.fillna(x.mean()))
#
# NameError: name 'df_male' is not defined

# %%
df_fill_age

# %%
df.describe(include='all').round(2)

# %%
df_male.Year

# %%
# KIBANA #
Username = 'elastic'
Password = 'NGSgSDLqYhnotXvrdMbUbChP'
