# %%
from IPython import display

# %% [markdown]
# ### Nivell 1
# - Exercici 1
#
# Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# + per aquest exemple specific m'he creat un compte a https://www.elastic.co/es
# + amb aquest compte trial puc entrar al sistema i treballar desde l'aplicatiu WEB

# %% [markdown]
# + creo un deployment

# %%
display.Image('picture_1.png')

# %% [markdown]
# + i desde aqui me'n vaig a Quick Link de Kibana on em mostra les diferents opcions de visualització

# %%
display.Image('picture_2.png')

# %% [markdown]
# + me'n vaig a Dashboard

# %%
display.Image('picture_3.png')

# %% [markdown]
# + agafaré el 2nd exemple per treballar amb les dades 'Global Flight Dashboard' que hi ha d'exemple

# %% [markdown]
# + s'obre el dashboard on puc editar les diferentes visualitzacions

# %%
display.Image('picture_4.png')

# %% [markdown]
# + A share es pot guardar un PDF del dashboard

# %% [markdown]
# ### Nivell 2
# - Exercici 1
#
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# + per realitzar aquesta tasca pujo el seguent CSV al elastic cloud
# + Dades de les diferents olimpiades, noms, pais, sexe,sport,..
# + el dataset es el seguent:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('modern_games.csv')
#df.drop('Unnamed: 0',axis=1,inplace=True)
#df.drop_duplicates(keep='first',inplace=True,ignore_index=True)
df.head()
# Out:
#                        Name Sex   Age  Height  Weight         Team  NOC  Year  \
# 0                 A Dijiang   M  24.0   180.0    80.0        China  CHN  1992
# 1                  A Lamusi   M  23.0   170.0    60.0        China  CHN  2012
# 2  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED  1988
# 3  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED  1992
# 4  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED  1994
#
#    Season         City          Sport Medal
# 0  Summer    Barcelona     Basketball   NaN
# 1  Summer       London           Judo   NaN
# 2  Winter      Calgary  Speed Skating   NaN
# 3  Winter  Albertville  Speed Skating   NaN
# 4  Winter  Lillehammer  Speed Skating   NaN

# %% [markdown]
# + he pujat el CSV al elastic cloud i he començat a construir el DASHBOARD amb les dades de les olimpiades

# %%
display.Image('report.PNG')
# Dashboard basic d'analitzar algunes dades i visualitzarles

# %% [markdown]
# al git tambe es pot trobar el report : MFF_games_S19T01_exercici_2.pdf

# %% [markdown]
# ### Nivell 3
# - Exercici 1
#
# Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %%
display.Image('report_full1.png')
# Dashboard full de les dades de olympic games

# %%
display.Image('report_full2.png')
# Dashboard full de les dades de olympic games

# %%
display.Image('report_full3.png')
# Dashboard full de les dades de olympic games

# %% [markdown]
# + Ho sento he hagut de fer "pantallazos" perque alhora de generar un report en pdf o png fallaba.

# %% [markdown]
# + M'agradaria haver fet un Cloud Word pero no podia amb les meves dades
